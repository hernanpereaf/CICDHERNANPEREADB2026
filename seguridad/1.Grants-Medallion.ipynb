-- %% [markdown]
-- ##Grants

-- %%
%python
dbutils.widgets.removeAll()

-- %%
create widget text storageName default "adlsproyecto2026";
create widget text catalogo default "ventas";

-- %%
%python
storageName = dbutils.widgets.get("storageName")
catalogo = dbutils.widgets.get("catalogo")

-- %%
GRANT SELECT ON TABLE ${catalogo}.bronze.stores TO `heper__1979@outlook.com`;
GRANT SELECT ON TABLE ${catalogo}.bronze.stores TO `heper__1979@outlook.com`;
GRANT SELECT ON TABLE ${catalogo}.bronze.stores TO `heper__1979@outlook.com`;

GRANT SELECT ON TABLE ${catalogo}.silver.sales_stores_transformed TO `heper__1979@outlook.com`;

GRANT SELECT ON TABLE ${catalogo}.golden.golden_sales_partitioned TO `heper__1979@outlook.com`;

-- %%
GRANT USE CATALOG ON CATALOG ventas TO `heper__1979@outlook.com`;

-- %%
GRANT CREATE TABLE ON SCHEMA ${catalogo}.bronze TO `heper__1979@outlook.com`;
GRANT CREATE TABLE ON SCHEMA ${catalogo}.silver TO `heper__1979@outlook.com`;
GRANT CREATE TABLE ON SCHEMA ${catalogo}.golden TO `heper__1979@outlook.com`;

-- %%
CREATE GROUP `data_engineers`;
CREATE GROUP `Desarrolladores`;
CREATE GROUP `Admins_Smart`;

-- %%
ALTER GROUP `data_engineers`
ADD USER `heper__1979@outlook.com`;

ALTER GROUP `Desarrolladores`
ADD USER `heper__1979@outlook.com`;

ALTER GROUP `Admins_Smart`
ADD USER `heper__1979@outlook.com`;

-- %%
SHOW USERS;

-- %%
GRANT USE SCHEMA ON SCHEMA ventas.bronze TO `heper__1979@outlook.com`;

GRANT USE SCHEMA ON SCHEMA ventas.bronze TO `Desarrolladores`;
GRANT CREATE ON SCHEMA ventas.bronze TO `Desarrolladores`;

-- %%
GRANT SELECT ON TABLE ${catalogo}.bronze.stores TO `Admins_Smart`;
GRANT SELECT ON TABLE ${catalogo}.bronze.sales TO `Admins_Smart`;
GRANT SELECT ON TABLE ${catalogo}.bronze.brands TO `Admins_Smart`;
GRANT SELECT ON TABLE ${catalogo}.silver.sales_stores_transformed TO `Analistas`;

-- GRANT CREATE ON CATALOG demo_catalog TO `Dvelopers`;
-- GRANT SELECT ON CATALOG demo_catalog TO `Dvelopers`;
-- GRANT ALL PRIVILEGES ON CATALOG demo_catalog TO `Admins`;

-- %%
SHOW GRANTS ON TABLE ${catalogo}.bronze.stores;
SHOW GRANTS ON TABLE ${catalogo}.bronze.sales;
SHOW GRANTS ON TABLE ${catalogo}.bronze.brands;

-- %%
SHOW GRANTS ON SCHEMA ${catalogo}.bronze;

-- %%
SHOW GRANTS ON CATALOG ${catalogo};

-- %%
SHOW GRANTS ON SCHEMA ${catalogo}.bronze;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`

-- %%
GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `heper__1979@outlook.com`;

-- %%
GRANT WRITE FILES
ON EXTERNAL LOCATION `exlt-bronze`
TO `heper__1979@outlook.com`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-bronze`
TO `heper__1979@outlook.com`;
